# %% [markdown]
# # Docling Worker
# Notebook này chỉ cài môi trường và khởi động worker. Logic Docling nằm trong processing/docling.

# %%
# !pip install -q -r requirements-colab.txt

# %%
import os
os.environ['API_BASE_URL'] = 'https://YOUR-FASTAPI-URL'
os.environ['WORKER_TOKEN'] = 'YOUR-WORKER-TOKEN'
os.environ['SUPABASE_URL'] = 'YOUR-SUPABASE-URL'
os.environ['SUPABASE_KEY'] = 'YOUR-SUPABASE-KEY'

# %%
from workers.colab.docling_worker import start_docling_worker
start_docling_worker()
